# %%
from train_my_dyprag_104 import *
embedding_model_path = "./models/long-t5-tglobal-base"
translator_path = "./models/Llama-3.2-1B-Instruct-Doc_mask-longt5_capt_57/translator_step_72270.safetensors"
device = "cuda:0"
embedding_model = AutoModel.from_pretrained(embedding_model_path,device_map=device)
embedding_tokenizer = AutoTokenizer.from_pretrained(embedding_model_path)
llm_model_path = "./models/Llama-3.2-1B-Instruct-Doc_mask"
llm_model = AutoModelForCausalLM.from_pretrained(llm_model_path, device_map="cpu")
translator = CrossAttentionParameterTranslator(
            embedding_model=embedding_model,
            llm_model=llm_model,
            lora_rank=2,
            projector_hidden_dim=1024,
            attn_heads=8,
            attn_ff_dim=1024,
            cross_layers=1,
            encoder_layers=1,
        )
def _get_full_doc_embed(passages):

    def _bge_or_snowflake_embed(model, inputs):
        output = model(**inputs)
        embeddings = output.last_hidden_state #[B, L, D]
        return torch.nn.functional.normalize(embeddings, p=2, dim=-1)

    def _t5_embed(model, inputs):
        output = model.encoder(**inputs)
        embeddings = output.last_hidden_state
        return embeddings #[B, L, D]

    with torch.no_grad():
        inputs = embedding_tokenizer(
            passages,
            return_tensors="pt",
            padding="longest",
            max_length=4096,
            truncation=True
        ).to(device)

        model_name = embedding_model.name_or_path.lower()

        if 'bge' in model_name or 'snowflake' in model_name:
            sentence_embeddings = _bge_or_snowflake_embed(embedding_model, inputs)
        elif 't5' in model_name:
            sentence_embeddings = _t5_embed(embedding_model, inputs)
        else:
            raise NotImplementedError(f"[Unsupported Model] {model_name}")

    return sentence_embeddings, inputs["attention_mask"]
translator.to(device)
translator.load_state_dict(load_file(translator_path, device=device))
# Out:
# <All keys matched successfully>

# %%
passages = ["hello world", "hello world", "hello world"]
doc_embed,attention_mask = _get_full_doc_embed(passages)
with torch.no_grad():
    lora_weights = translator(doc_embed,attention_mask.to(translator.device))

print(lora_weights)
print(len(lora_weights))
print(lora_weights['base_model.model.model.layers.15.mlp.gate_proj.lora_A.weight'].shape)
print(lora_weights['base_model.model.model.layers.15.mlp.gate_proj.lora_B.weight'].shape)
print(lora_weights['base_model.model.model.layers.15.mlp.up_proj.lora_A.weight'].shape)
print(lora_weights['base_model.model.model.layers.15.mlp.up_proj.lora_B.weight'].shape)
print(lora_weights['base_model.model.model.layers.15.mlp.down_proj.lora_A.weight'].shape)
print(lora_weights['base_model.model.model.layers.15.mlp.down_proj.lora_B.weight'].shape)
# Out:
# defaultdict(<class 'list'>, {'base_model.model.model.layers.0.mlp.down_proj.lora_A.weight': tensor([[[-0.0165,  0.2540,  0.8407,  ..., -0.1998, -0.6043, -0.6351],
#          [ 1.5179, -1.0672, -0.4722,  ..., -0.1787,  1.0244,  0.7010]],
#
#         [[-0.0696,  0.3420,  0.6513,  ..., -0.2589, -0.5729, -0.6033],
#          [ 1.4940, -1.0691, -0.3171,  ..., -0.2076,  0.8030,  0.7242]],
#
#         [[ 0.0546,  0.2315,  0.7426,  ..., -0.1940, -0.5675, -0.5227],
#          [ 1.5018, -1.2771, -0.4343,  ..., -0.2175,  0.9931,  0.8090]]],
#        device='cuda:0'), 'base_model.model.model.layers.0.mlp.down_proj.lora_B.weight': tensor([[[-1.2099e-04, -3.6793e-04],
#          [ 2.4385e-05,  4.2279e-04],
#          [ 4.8415e-04, -5.8368e-04],
#          ...,
#          [-8.1272e-05, -2.5132e-04],
#          [-1.6941e-04, -8.1658e-05],
#          [ 3.0678e-05,  1.8897e-05]],
#
#         [[-7.1263e-05, -4.2085e-04],
#          [ 5.0107e-05,  4.9522e-04],
#          [ 5.0658e-04, -6.3057e-04],
#          ...,
#          [-1.2842e-04, -2.1899e-04],
#          [-1.4072e-04, -9.7726e-05],
#          [ 7.9745e-05,  4.9493e-05]],
#
#         [[-8.4046e-05, -4.0926e-04],
#          [ 1.5576e-05,  4.4638e-04],
#          [ 5.2266e-04, -6.3676e-04],
#          ...,
#          [-9.6612e-05, -2.1441e-04],
#          [-1.0202e-04, -1.2448e-04],
#          [ 2.9840e-06,  7.6669e-05]]], device='cuda:0'), 'base_model.model.model.layers.1.mlp.down_proj.lora_A.weight': tensor([[[ 0.0030,  0.3017,  0.7234,  ..., -0.2420, -0.5710, -0.7276],
#          [ 1.5504, -1.0191, -0.3064,  ..., -0.1509,  0.9717,  0.7448]],
#
#         [[-0.0535,  0.2558,  0.6289,  ..., -0.1641, -0.5188, -0.4769],
#          [ 1.3231, -1.1477, -0.3488,  ..., -0.1607,  0.7729,  0.4387]],
#
#         [[-0.1926,  0.1256,  0.7239,  ..., -0.0486, -0.6019, -0.5923],
#          [ 1.5010, -1.1895, -0.3745,  ..., -0.0764,  0.8506,  0.6208]]],
#        device='cuda:0'), 'base_model.model.model.layers.1.mlp.down_proj.lora_B.weight': tensor([[[-1.6091e-04, -4.5155e-04],
#          [ 4.9201e-06,  5.1228e-04],
#          [ 4.8418e-04, -6.0156e-04],
#          ...,
#          [-1.1785e-04, -2.9340e-04],
#          [-1.9600e-04, -4.6995e-05],
#          [ 9.5603e-06,  2.1193e-05]],
#
#         [[-7.6201e-05, -3.5675e-04],
#          [ 1.6981e-05,  4.6662e-04],
#          [ 4.6825e-04, -5.8079e-04],
#          ...,
#          [-6.9185e-05, -2.5778e-04],
#          [-1.7124e-04, -6.4188e-05],
#          [ 1.7198e-05,  7.5594e-06]],
#
#         [[-1.5955e-04, -3.7166e-04],
#          [ 2.7844e-05,  4.6420e-04],
#          [ 4.7921e-04, -5.7111e-04],
#          ...,
#          [-1.2158e-04, -2.2538e-04],
#          [-2.0527e-04, -3.3350e-05],
#          [ 1.8315e-05,  1.6280e-06]]], device='cuda:0'), 'base_model.model.model.layers.2.mlp.down_proj.lora_A.weight': tensor([[[-0.0630,  0.2154,  0.8566,  ..., -0.1539, -0.5243, -0.5576],
#          [ 1.6596, -1.1238, -0.3571,  ..., -0.1988,  0.9105,  0.8626]],
#
#         [[-0.0077,  0.1977,  0.9143,  ..., -0.0510, -0.4800, -0.5711],
#          [ 1.5523, -1.0111, -0.3143,  ..., -0.0499,  0.8840,  0.9325]],
#
#         [[-0.0052,  0.2054,  0.8275,  ..., -0.1350, -0.6631, -0.5967],
#          [ 1.5511, -1.0189, -0.2866,  ..., -0.1081,  0.8300,  0.8354]]],
#        device='cuda:0'), 'base_model.model.model.layers.2.mlp.down_proj.lora_B.weight': tensor([[[-1.1255e-04, -4.4720e-04],
#          [ 4.7256e-05,  4.2606e-04],
#          [ 5.7668e-04, -6.7146e-04],
#          ...,
#          [-8.7682e-05, -1.8400e-04],
#          [-1.3544e-04, -1.2763e-04],
#          [ 1.5125e-05,  9.0957e-05]],
#
#         [[-1.2108e-04, -4.1338e-04],
#          [ 3.8095e-06,  4.6172e-04],
#          [ 5.4169e-04, -6.3793e-04],
#          ...,
#          [-1.0857e-04, -1.8277e-04],
#          [-1.2695e-04, -8.8390e-05],
#          [ 6.0393e-05,  2.4605e-05]],
#
#         [[-9.6950e-05, -4.3652e-04],
#          [ 7.9935e-05,  4.6496e-04],
#          [ 4.9760e-04, -6.0878e-04],
#          ...,
#          [-8.0545e-05, -2.3256e-04],
#          [-1.2319e-04, -8.8464e-05],
#          [ 2.4112e-05,  2.5811e-05]]], device='cuda:0'), 'base_model.model.model.layers.3.mlp.down_proj.lora_A.weight': tensor([[[ 0.1050,  0.1915,  0.8179,  ..., -0.1372, -0.6733, -0.7296],
#          [ 1.6589, -1.1021, -0.2124,  ..., -0.1909,  1.0083,  0.8331]],
#
#         [[ 0.0242,  0.0584,  0.7714,  ..., -0.1160, -0.5482, -0.6285],
#          [ 1.4326, -0.9704, -0.2180,  ..., -0.1759,  0.8902,  0.8244]],
#
#         [[-0.1152,  0.2867,  0.7613,  ..., -0.0181, -0.5249, -0.7774],
#          [ 1.5686, -0.9899, -0.2871,  ..., -0.2036,  0.9990,  0.8252]]],
#        device='cuda:0'), 'base_model.model.model.layers.3.mlp.down_proj.lora_B.weight': tensor([[[-9.6727e-05, -4.6794e-04],
#          [ 1.3519e-05,  4.9635e-04],
#          [ 5.4866e-04, -7.1897e-04],
#          ...,
#          [-8.9135e-05, -2.7064e-04],
#          [-8.7542e-05, -1.7206e-04],
#          [ 8.2247e-05, -3.4558e-06]],
#
#         [[-1.2170e-04, -3.7399e-04],
#          [ 5.4201e-05,  5.1170e-04],
#          [ 4.6054e-04, -5.9482e-04],
#          ...,
#          [-1.1780e-04, -1.6666e-04],
#          [-1.1981e-04, -1.2583e-04],
#          [ 6.4192e-05, -1.8311e-05]],
#
#         [[-7.6184e-05, -3.7271e-04],
#          [-3.8001e-07,  4.2360e-04],
#          [ 4.7809e-04, -5.5084e-04],
#          ...,
#          [-3.3670e-05, -1.8588e-04],
#          [-1.3925e-04, -9.6784e-05],
#          [ 2.4836e-05,  1.3764e-05]]], device='cuda:0'), 'base_model.model.model.layers.4.mlp.down_proj.lora_A.weight': tensor([[[-0.0617,  0.2217,  0.7827,  ..., -0.1034, -0.6556, -0.6759],
#          [ 1.3970, -1.1024, -0.2712,  ..., -0.1639,  0.7272,  0.8676]],
#
#         [[ 0.0201,  0.2767,  0.7167,  ...,  0.0021, -0.6029, -0.6543],
#          [ 1.4729, -0.9355, -0.4313,  ..., -0.1172,  0.8896,  0.8912]],
#
#         [[-0.0752,  0.1596,  0.6568,  ..., -0.2441, -0.5176, -0.6251],
#          [ 1.4751, -1.0481, -0.3163,  ..., -0.2891,  0.7519,  0.7533]]],
#        device='cuda:0'), 'base_model.model.model.layers.4.mlp.down_proj.lora_B.weight': tensor([[[-1.3105e-04, -3.8757e-04],
#          [ 3.2091e-05,  4.9361e-04],
#          [ 5.1297e-04, -5.2623e-04],
#          ...,
#          [-6.4060e-05, -2.0844e-04],
#          [-1.6487e-04, -1.3762e-04],
#          [ 5.9879e-05, -1.5588e-05]],
#
#         [[-1.3287e-04, -4.2345e-04],
#          [ 3.2647e-05,  4.3156e-04],
#          [ 4.6158e-04, -5.8750e-04],
#          ...,
#          [-1.2618e-04, -2.4833e-04],
#          [-1.8119e-04, -8.5196e-05],
#          [ 3.3325e-05, -3.4972e-06]],
#
#         [[-9.9737e-05, -4.0295e-04],
#          [ 4.1414e-05,  4.5244e-04],
#          [ 4.7395e-04, -5.3673e-04],
#          ...,
#          [-9.2688e-05, -2.3712e-04],
#          [-1.4791e-04, -8.0263e-05],
#          [-4.8457e-05,  5.4743e-05]]], device='cuda:0'), 'base_model.model.model.layers.5.mlp.down_proj.lora_A.weight': tensor([[[-0.0146,  0.1034,  0.7089,  ..., -0.1020, -0.6240, -0.7147],
#          [ 1.5118, -1.1162, -0.4434,  ..., -0.1538,  0.9975,  0.8292]],
#
#         [[-0.0644,  0.1939,  0.8729,  ..., -0.1656, -0.6006, -0.6739],
#          [ 1.4905, -1.1283, -0.3989,  ..., -0.1210,  0.9255,  0.7258]],
#
#         [[-0.0855,  0.3461,  0.7864,  ..., -0.1097, -0.7850, -0.7470],
#          [ 1.4483, -1.1528, -0.3548,  ..., -0.1086,  0.9121,  0.6750]]],
#        device='cuda:0'), 'base_model.model.model.layers.5.mlp.down_proj.lora_B.weight': tensor([[[-1.1796e-04, -3.7305e-04],
#          [ 1.5397e-05,  5.1259e-04],
#          [ 5.1040e-04, -6.6866e-04],
#          ...,
#          [-1.2014e-04, -2.8815e-04],
#          [-1.6189e-04, -9.5802e-05],
#          [ 4.1404e-05,  2.8286e-05]],
#
#         [[-1.1175e-04, -3.8985e-04],
#          [ 9.8752e-05,  4.4905e-04],
#          [ 4.9172e-04, -5.6370e-04],
#          ...,
#          [-1.1729e-04, -2.6205e-04],
#          [-2.0525e-04, -1.1289e-04],
#          [ 1.8325e-05,  4.0157e-05]],
#
#         [[-7.2698e-05, -3.6961e-04],
#          [-4.7859e-06,  4.5003e-04],
#          [ 5.0246e-04, -6.2602e-04],
#          ...,
#          [-8.3064e-05, -2.3409e-04],
#          [-1.7101e-04, -1.0470e-04],
#          [ 1.0633e-05,  8.3506e-05]]], device='cuda:0'), 'base_model.model.model.layers.6.mlp.down_proj.lora_A.weight': tensor([[[ 0.0426,  0.3165,  0.8197,  ..., -0.1638, -0.6209, -0.6993],
#          [ 1.5439, -1.0915, -0.4982,  ..., -0.1904,  0.9025,  0.8015]],
#
#         [[ 0.0813,  0.3090,  0.6441,  ..., -0.0556, -0.6292, -0.7431],
#          [ 1.6352, -1.0973, -0.3072,  ..., -0.1803,  0.8963,  0.7778]],
#
#         [[ 0.0534,  0.1890,  0.7046,  ..., -0.2194, -0.6047, -0.7140],
#          [ 1.5405, -0.8921, -0.3613,  ..., -0.1495,  0.8866,  0.9265]]],
#        device='cuda:0'), 'base_model.model.model.layers.6.mlp.down_proj.lora_B.weight': tensor([[[-1.0260e-04, -4.0640e-04],
#          [ 6.0807e-05,  4.5889e-04],
#          [ 4.8355e-04, -6.2472e-04],
#          ...,
#          [-1.0454e-04, -2.3053e-04],
#          [-1.2903e-04, -8.9377e-05],
#          [ 3.4358e-05, -2.0582e-05]],
#
#         [[-7.0094e-05, -4.0788e-04],
#          [-2.4059e-05,  4.8481e-04],
#          [ 4.9555e-04, -6.3374e-04],
#          ...,
#          [-6.3922e-05, -2.2738e-04],
#          [-1.2658e-04, -8.9334e-05],
#          [ 1.4012e-05,  2.0119e-05]],
#
#         [[-1.2331e-04, -4.0936e-04],
#          [-4.8938e-05,  4.6456e-04],
#          [ 4.7149e-04, -5.5582e-04],
#          ...,
#          [-1.0947e-04, -2.4854e-04],
#          [-1.3211e-04, -3.0649e-05],
#          [ 3.2045e-05,  2.9179e-05]]], device='cuda:0'), 'base_model.model.model.layers.7.mlp.down_proj.lora_A.weight': tensor([[[-0.0134,  0.2721,  0.7506,  ..., -0.0805, -0.6669, -0.6507],
#          [ 1.5743, -1.1048, -0.3213,  ..., -0.1055,  1.0327,  0.7581]],
#
#         [[-0.0312,  0.3006,  0.7247,  ..., -0.0539, -0.6489, -0.7468],
#          [ 1.5880, -1.1559, -0.2106,  ..., -0.1857,  0.9152,  0.7490]],
#
#         [[-0.0852,  0.2881,  0.6821,  ..., -0.1882, -0.5952, -0.7966],
#          [ 1.6437, -0.9917, -0.3154,  ..., -0.2388,  0.8977,  0.7497]]],
#        device='cuda:0'), 'base_model.model.model.layers.7.mlp.down_proj.lora_B.weight': tensor([[[-1.0233e-04, -4.0509e-04],
#          [ 1.1066e-05,  4.6915e-04],
#          [ 4.9638e-04, -6.1373e-04],
#          ...,
#          [-1.3799e-04, -2.4539e-04],
#          [-1.5132e-04, -3.8745e-05],
#          [ 2.8055e-06, -4.2593e-05]],
#
#         [[-4.4438e-05, -4.3440e-04],
#          [-3.0663e-05,  4.6557e-04],
#          [ 4.9096e-04, -5.8996e-04],
#          ...,
#          [-1.1399e-04, -2.2426e-04],
#          [-1.8732e-04, -1.3486e-04],
#          [ 2.5143e-05,  3.4754e-05]],
#
#         [[-7.6340e-05, -4.4302e-04],
#          [-2.7327e-05,  4.8762e-04],
#          [ 4.9821e-04, -6.3430e-04],
#          ...,
#          [-1.0670e-04, -2.8291e-04],
#          [-1.1222e-04, -1.6643e-04],
#          [ 6.5387e-05, -1.8458e-05]]], device='cuda:0'), 'base_model.model.model.layers.8.mlp.down_proj.lora_A.weight': tensor([[[ 0.1066,  0.1396,  0.7416,  ..., -0.1837, -0.5915, -0.6517],
#          [ 1.6618, -1.0086, -0.3139,  ..., -0.1572,  0.9590,  0.7793]],
#
#         [[-0.1012,  0.1554,  0.8408,  ..., -0.0205, -0.5392, -0.5781],
#          [ 1.5955, -1.0932, -0.2981,  ..., -0.0918,  0.9836,  0.8099]],
#
#         [[-0.0790,  0.2481,  0.7980,  ..., -0.2235, -0.7745, -0.6139],
#          [ 1.5433, -1.0253, -0.1974,  ..., -0.0694,  0.9041,  0.7494]]],
#        device='cuda:0'), 'base_model.model.model.layers.8.mlp.down_proj.lora_B.weight': tensor([[[-1.1707e-04, -4.3308e-04],
#          [-2.4504e-05,  5.0298e-04],
#          [ 5.0321e-04, -6.1720e-04],
#          ...,
#          [-1.6638e-04, -2.2346e-04],
#          [-1.9877e-04, -1.3026e-04],
#          [ 4.3241e-05, -2.8918e-05]],
#
#         [[-1.0114e-04, -4.5787e-04],
#          [ 5.3827e-05,  4.5950e-04],
#          [ 5.0793e-04, -6.5764e-04],
#          ...,
#          [-5.0917e-05, -2.3905e-04],
#          [-1.1962e-04, -4.7616e-05],
#          [ 6.3939e-05,  2.9114e-05]],
#
#         [[-1.0235e-04, -4.5449e-04],
#          [-6.0288e-06,  4.6283e-04],
#          [ 5.2038e-04, -6.2484e-04],
#          ...,
#          [-9.5290e-05, -2.5893e-04],
#          [-1.4140e-04, -1.1620e-04],
#          [ 5.9385e-05, -1.9272e-05]]], device='cuda:0'), 'base_model.model.model.layers.9.mlp.down_proj.lora_A.weight': tensor([[[ 0.0617,  0.1682,  0.6044,  ..., -0.1032, -0.5719, -0.6288],
#          [ 1.4646, -1.1166, -0.3081,  ..., -0.1938,  0.8091,  0.7577]],
#
#         [[-0.0369,  0.0191,  0.6647,  ..., -0.0740, -0.6046, -0.6937],
#          [ 1.6275, -1.0464, -0.3512,  ..., -0.2336,  0.8620,  0.8082]],
#
#         [[-0.0161,  0.1053,  0.5659,  ..., -0.3388, -0.6187, -0.5884],
#          [ 1.4815, -1.0749, -0.4039,  ..., -0.1389,  0.7931,  0.6841]]],
#        device='cuda:0'), 'base_model.model.model.layers.9.mlp.down_proj.lora_B.weight': tensor([[[-1.1915e-04, -3.9494e-04],
#          [-5.0947e-05,  4.7121e-04],
#          [ 4.7296e-04, -6.2820e-04],
#          ...,
#          [-8.9125e-05, -2.6948e-04],
#          [-1.5514e-04, -9.9241e-05],
#          [ 7.7520e-05, -1.6123e-05]],
#
#         [[-1.2146e-04, -4.4151e-04],
#          [-6.6276e-05,  4.7463e-04],
#          [ 4.9593e-04, -6.6153e-04],
#          ...,
#          [-1.3118e-04, -2.1052e-04],
#          [-1.4239e-04, -9.6435e-05],
#          [ 5.0068e-05,  5.5986e-05]],
#
#         [[-1.2025e-04, -3.9741e-04],
#          [ 3.2037e-05,  4.3890e-04],
#          [ 4.8857e-04, -6.1458e-04],
#          ...,
#          [-1.5650e-04, -2.6607e-04],
#          [-1.5857e-04, -1.4906e-04],
#          [ 7.7876e-05, -2.6934e-05]]], device='cuda:0'), 'base_model.model.model.layers.10.mlp.down_proj.lora_A.weight': tensor([[[ 7.4616e-04,  9.0661e-02,  8.6221e-01,  ..., -1.8274e-01,
#           -5.7396e-01, -5.4930e-01],
#          [ 1.5359e+00, -1.0852e+00, -4.3215e-01,  ..., -2.4997e-01,
#            8.7666e-01,  7.4444e-01]],
#
#         [[-2.2041e-01,  2.4579e-01,  6.8860e-01,  ..., -1.0128e-01,
#           -4.9574e-01, -5.7909e-01],
#          [ 1.4888e+00, -1.0169e+00, -2.9751e-01,  ..., -8.6094e-02,
#            7.0897e-01,  7.4340e-01]],
#
#         [[-2.3428e-02,  2.1789e-01,  7.3897e-01,  ..., -2.5022e-01,
#           -6.4256e-01, -7.4293e-01],
#          [ 1.6684e+00, -9.8789e-01, -3.8609e-01,  ..., -1.8099e-01,
#            9.9359e-01,  7.3640e-01]]], device='cuda:0'), 'base_model.model.model.layers.10.mlp.down_proj.lora_B.weight': tensor([[[-1.2800e-04, -4.0542e-04],
#          [ 3.1659e-05,  4.7988e-04],
#          [ 4.4993e-04, -6.2017e-04],
#          ...,
#          [ 1.4924e-07, -2.3057e-04],
#          [-1.2921e-04, -1.0204e-04],
#          [ 3.8701e-05, -5.7051e-06]],
#
#         [[-1.1247e-04, -3.3958e-04],
#          [-7.4757e-06,  4.3475e-04],
#          [ 4.8665e-04, -5.4342e-04],
#          ...,
#          [-8.6690e-05, -2.3142e-04],
#          [-1.3273e-04, -6.6718e-05],
#          [ 4.5807e-05, -1.9960e-05]],
#
#         [[-8.0475e-05, -4.4987e-04],
#          [ 1.3627e-05,  4.8738e-04],
#          [ 4.8540e-04, -7.6401e-04],
#          ...,
#          [-6.2175e-05, -2.9668e-04],
#          [-1.6823e-04, -8.8050e-05],
#          [ 5.0054e-05,  1.8484e-05]]], device='cuda:0'), 'base_model.model.model.layers.11.mlp.down_proj.lora_A.weight': tensor([[[ 0.0252,  0.1410,  0.8273,  ..., -0.0777, -0.5194, -0.6582],
#          [ 1.6427, -1.1145, -0.3666,  ..., -0.1454,  0.8815,  0.8623]],
#
#         [[ 0.0359,  0.2358,  0.7441,  ..., -0.1133, -0.5044, -0.7120],
#          [ 1.6146, -1.1181, -0.3105,  ..., -0.1974,  1.0203,  0.9251]],
#
#         [[-0.1305,  0.2559,  0.8190,  ..., -0.1103, -0.6527, -0.7077],
#          [ 1.5607, -1.1107, -0.3395,  ..., -0.3414,  0.9571,  0.7951]]],
#        device='cuda:0'), 'base_model.model.model.layers.11.mlp.down_proj.lora_B.weight': tensor([[[-6.8906e-05, -3.6841e-04],
#          [ 2.7739e-05,  4.3187e-04],
#          [ 5.4164e-04, -6.1712e-04],
#          ...,
#          [-6.8320e-05, -2.4438e-04],
#          [-1.2282e-04, -1.2135e-04],
#          [ 6.9148e-05,  2.9361e-05]],
#
#         [[-1.7966e-04, -4.0028e-04],
#          [-2.9257e-05,  4.8595e-04],
#          [ 5.1044e-04, -6.4802e-04],
#          ...,
#          [-1.2457e-04, -2.7633e-04],
#          [-1.2737e-04, -1.3789e-04],
#          [ 5.9132e-05,  3.5837e-06]],
#
#         [[-1.4046e-04, -4.1269e-04],
#          [-5.2188e-06,  5.0728e-04],
#          [ 4.6755e-04, -6.0002e-04],
#          ...,
#          [-1.5474e-04, -2.0895e-04],
#          [-1.7102e-04, -1.4508e-04],
#          [ 7.1894e-05,  2.8291e-05]]], device='cuda:0'), 'base_model.model.model.layers.12.mlp.down_proj.lora_A.weight': tensor([[[-0.1001,  0.3648,  0.6472,  ..., -0.0680, -0.6509, -0.6930],
#          [ 1.5316, -1.1150, -0.2964,  ..., -0.1542,  0.9561,  0.8403]],
#
#         [[-0.1656,  0.1947,  0.6714,  ..., -0.0814, -0.5740, -0.6783],
#          [ 1.7163, -0.9550, -0.3032,  ..., -0.0985,  0.9969,  0.7082]],
#
#         [[-0.0885,  0.0892,  0.7435,  ..., -0.0453, -0.5901, -0.7002],
#          [ 1.4937, -1.0065, -0.4036,  ..., -0.1322,  0.9816,  0.7053]]],
#        device='cuda:0'), 'base_model.model.model.layers.12.mlp.down_proj.lora_B.weight': tensor([[[-9.9512e-05, -3.9499e-04],
#          [ 3.6048e-05,  4.4465e-04],
#          [ 4.9705e-04, -5.8221e-04],
#          ...,
#          [-5.7502e-05, -2.6220e-04],
#          [-1.5090e-04, -1.6407e-04],
#          [ 1.2867e-05,  3.9961e-05]],
#
#         [[-9.8565e-05, -3.8198e-04],
#          [ 1.9899e-05,  4.8638e-04],
#          [ 4.9810e-04, -6.7361e-04],
#          ...,
#          [-1.0940e-04, -2.7988e-04],
#          [-1.3516e-04, -1.1300e-04],
#          [ 2.2981e-05,  6.2322e-06]],
#
#         [[-1.1547e-04, -4.4525e-04],
#          [ 3.5151e-05,  4.4136e-04],
#          [ 4.3828e-04, -6.2621e-04],
#          ...,
#          [-9.5560e-05, -2.4673e-04],
#          [-8.7028e-05, -1.1068e-04],
#          [ 1.5601e-05,  2.1828e-05]]], device='cuda:0'), 'base_model.model.model.layers.13.mlp.down_proj.lora_A.weight': tensor([[[-0.0032,  0.0843,  0.5930,  ..., -0.0361, -0.5265, -0.6154],
#          [ 1.4995, -1.0945, -0.3022,  ..., -0.0907,  0.8673,  0.7756]],
#
#         [[-0.0525,  0.1623,  0.5989,  ..., -0.0908, -0.5444, -0.6353],
#          [ 1.3758, -0.8617, -0.2321,  ..., -0.2307,  0.8569,  0.7175]],
#
#         [[-0.1084,  0.0559,  0.6736,  ..., -0.0956, -0.5622, -0.7707],
#          [ 1.4578, -1.0234, -0.3222,  ..., -0.1438,  0.8374,  0.8229]]],
#        device='cuda:0'), 'base_model.model.model.layers.13.mlp.down_proj.lora_B.weight': tensor([[[-9.5658e-05, -4.0209e-04],
#          [ 2.8926e-05,  4.9894e-04],
#          [ 4.9024e-04, -5.9322e-04],
#          ...,
#          [-1.0134e-04, -1.8383e-04],
#          [-1.2277e-04, -1.0138e-04],
#          [ 6.3496e-05,  4.6950e-06]],
#
#         [[-8.8992e-05, -3.9482e-04],
#          [-2.5568e-05,  4.3769e-04],
#          [ 4.6303e-04, -5.6894e-04],
#          ...,
#          [-8.2672e-05, -1.9349e-04],
#          [-1.4454e-04, -9.9550e-05],
#          [ 4.3844e-05, -5.0584e-05]],
#
#         [[-9.9044e-05, -3.5432e-04],
#          [ 1.8300e-05,  4.3805e-04],
#          [ 5.2842e-04, -5.5848e-04],
#          ...,
#          [-9.7692e-05, -2.1567e-04],
#          [-1.0246e-04, -1.1820e-04],
#          [ 7.2274e-05,  9.4698e-05]]], device='cuda:0'), 'base_model.model.model.layers.14.mlp.down_proj.lora_A.weight': tensor([[[-0.0075,  0.0925,  0.8336,  ..., -0.0826, -0.6928, -0.5981],
#          [ 1.5587, -1.0144, -0.1206,  ..., -0.1790,  0.8482,  0.7016]],
#
#         [[-0.0313,  0.1855,  0.6771,  ..., -0.1096, -0.5781, -0.5849],
#          [ 1.5461, -1.1196, -0.2448,  ..., -0.1648,  0.8781,  0.8574]],
#
#         [[ 0.0469,  0.1553,  0.8682,  ..., -0.2083, -0.6756, -0.6711],
#          [ 1.5058, -1.1227, -0.2972,  ..., -0.1539,  0.9685,  0.8617]]],
#        device='cuda:0'), 'base_model.model.model.layers.14.mlp.down_proj.lora_B.weight': tensor([[[-1.1275e-04, -3.6257e-04],
#          [ 3.6727e-05,  4.4162e-04],
#          [ 4.8576e-04, -5.9206e-04],
#          ...,
#          [-8.5062e-05, -2.2630e-04],
#          [-1.3189e-04, -1.0294e-04],
#          [ 5.7308e-05,  2.5616e-05]],
#
#         [[-1.0849e-04, -4.2316e-04],
#          [ 8.1381e-06,  4.8300e-04],
#          [ 4.8602e-04, -6.2042e-04],
#          ...,
#          [-3.7485e-05, -1.7915e-04],
#          [-1.0579e-04, -1.0529e-04],
#          [ 6.3727e-05,  3.3823e-05]],
#
#         [[-1.4189e-04, -4.7050e-04],
#          [-6.5834e-06,  4.5965e-04],
#          [ 4.9628e-04, -6.3336e-04],
#          ...,
#          [-7.8536e-05, -1.8900e-04],
#          [-8.3720e-05, -8.6501e-05],
#          [ 5.2149e-05,  2.8571e-05]]], device='cuda:0'), 'base_model.model.model.layers.15.mlp.down_proj.lora_A.weight': tensor([[[ 0.0470,  0.2770,  0.7934,  ..., -0.0831, -0.5455, -0.6684],
#          [ 1.6906, -0.9817, -0.2107,  ..., -0.1369,  1.0419,  0.9174]],
#
#         [[-0.0601,  0.3196,  0.6715,  ...,  0.1152, -0.5380, -0.6524],
#          [ 1.4933, -0.9280, -0.2666,  ..., -0.2380,  0.9193,  0.7126]],
#
#         [[ 0.0714,  0.1790,  0.7735,  ..., -0.1688, -0.5318, -0.6125],
#          [ 1.5977, -1.0012, -0.2271,  ..., -0.0406,  0.9210,  0.9171]]],
#        device='cuda:0'), 'base_model.model.model.layers.15.mlp.down_proj.lora_B.weight': tensor([[[-9.2741e-05, -4.4074e-04],
#          [ 1.3976e-07,  4.8906e-04],
#          [ 4.6738e-04, -6.6276e-04],
#          ...,
#          [-4.4723e-05, -2.1673e-04],
#          [-1.2519e-04, -9.1824e-05],
#          [ 6.7022e-05, -1.5635e-05]],
#
#         [[-9.5081e-05, -4.4850e-04],
#          [ 1.9230e-05,  5.1356e-04],
#          [ 5.2957e-04, -7.4294e-04],
#          ...,
#          [-4.2997e-05, -2.0636e-04],
#          [-1.1981e-04, -1.4839e-04],
#          [ 1.1191e-04,  9.0687e-06]],
#
#         [[-8.7839e-05, -4.6804e-04],
#          [ 4.4092e-06,  5.2175e-04],
#          [ 4.7313e-04, -6.5488e-04],
#          ...,
#          [-9.2133e-05, -2.3563e-04],
#          [-1.1720e-04, -1.0777e-04],
#          [ 1.1014e-05, -1.4257e-05]]], device='cuda:0'), 'base_model.model.model.layers.0.mlp.up_proj.lora_A.weight': tensor([[[ 0.1788,  0.3882, -0.1717,  ...,  2.1624, -0.2606,  0.1180],
#          [-0.1528,  1.1297,  0.8274,  ...,  1.0285, -0.0610,  1.9729]],
#
#         [[ 0.3401,  0.4025,  0.0437,  ...,  2.1353, -0.3571,  0.1411],
#          [-0.1026,  1.1970,  0.8748,  ...,  0.9171, -0.0925,  1.9341]],
#
#         [[ 0.2504,  0.3294, -0.0930,  ...,  2.1497, -0.2957,  0.2463],
#          [ 0.0615,  1.1776,  0.8202,  ...,  1.0133, -0.0851,  2.0969]]],
#        device='cuda:0'), 'base_model.model.model.layers.0.mlp.up_proj.lora_B.weight': tensor([[[-3.4134e-04, -6.8394e-04],
#          [-5.3090e-04, -3.6926e-04],
#          [ 2.9043e-04, -1.8321e-04],
#          ...,
#          [ 5.3431e-04, -2.9520e-04],
#          [ 3.1615e-06,  5.8319e-04],
#          [-3.7148e-06, -2.4204e-04]],
#
#         [[-3.6709e-04, -7.2627e-04],
#          [-6.3942e-04, -4.4719e-04],
#          [ 2.6471e-04, -2.6017e-04],
#          ...,
#          [ 4.8386e-04, -2.8045e-04],
#          [ 4.3210e-05,  6.2729e-04],
#          [ 9.2038e-05, -2.9868e-04]],
#
#         [[-4.0327e-04, -7.2441e-04],
#          [-6.4838e-04, -4.0746e-04],
#          [ 2.6486e-04, -2.6620e-04],
#          ...,
#          [ 5.0850e-04, -3.0776e-04],
#          [ 7.2390e-05,  5.8454e-04],
#          [ 4.0592e-05, -2.1654e-04]]], device='cuda:0'), 'base_model.model.model.layers.1.mlp.up_proj.lora_A.weight': tensor([[[ 0.1407,  0.1774, -0.0937,  ...,  2.0297, -0.2018,  0.2873],
#          [-0.0941,  1.3478,  0.7359,  ...,  1.0350, -0.0395,  1.9587]],
#
#         [[ 0.0096,  0.3418,  0.0023,  ...,  2.0953, -0.2032,  0.1759],
#          [-0.1790,  1.3047,  0.9051,  ...,  1.0351, -0.0755,  2.0081]],
#
#         [[ 0.1671,  0.4911, -0.2078,  ...,  2.1682, -0.3330,  0.1242],
#          [-0.0456,  1.3005,  0.8646,  ...,  1.0158,  0.0682,  2.0831]]],
#        device='cuda:0'), 'base_model.model.model.layers.1.mlp.up_proj.lora_B.weight': tensor([[[-3.3352e-04, -8.1513e-04],
#          [-5.8981e-04, -4.1992e-04],
#          [ 2.8270e-04, -2.9706e-04],
#          ...,
#          [ 5.0314e-04, -3.1415e-04],
#          [ 6.6955e-05,  6.0938e-04],
#          [ 7.9440e-05, -2.8102e-04]],
#
#         [[-3.8683e-04, -6.6997e-04],
#          [-5.5577e-04, -3.8826e-04],
#          [ 2.9755e-04, -3.1246e-04],
#          ...,
#          [ 4.9889e-04, -2.5927e-04],
#          [ 2.5285e-05,  6.8110e-04],
#          [ 1.0155e-04, -3.0148e-04]],
#
#         [[-3.2785e-04, -7.3232e-04],
#          [-5.4346e-04, -3.7997e-04],
#          [ 2.9151e-04, -2.6020e-04],
#          ...,
#          [ 4.9736e-04, -3.2591e-04],
#          [ 2.5221e-05,  6.9492e-04],
#          [ 6.4754e-05, -2.9444e-04]]], device='cuda:0'), 'base_model.model.model.layers.2.mlp.up_proj.lora_A.weight': tensor([[[ 0.1472,  0.3070, -0.2511,  ...,  2.0324, -0.3482,  0.1586],
#          [-0.0136,  1.4240,  0.9225,  ...,  1.0997, -0.0648,  1.9566]],
#
#         [[ 0.2493,  0.4378, -0.1705,  ...,  2.0302, -0.2857,  0.1498],
#          [-0.1827,  1.2337,  0.9211,  ...,  1.0995,  0.0233,  1.9841]],
#
#         [[ 0.1948,  0.4128, -0.0896,  ...,  2.0044, -0.2756,  0.1318],
#          [ 0.0649,  1.3768,  0.7149,  ...,  0.9987, -0.0123,  2.0203]]],
#        device='cuda:0'), 'base_model.model.model.layers.2.mlp.up_proj.lora_B.weight': tensor([[[-3.7672e-04, -7.5386e-04],
#          [-5.8532e-04, -3.6361e-04],
#          [ 3.1541e-04, -2.4443e-04],
#          ...,
#          [ 5.7217e-04, -3.1433e-04],
#          [ 6.5319e-05,  5.9236e-04],
#          [ 7.0927e-05, -2.7011e-04]],
#
#         [[-3.5048e-04, -7.1972e-04],
#          [-5.2836e-04, -3.9032e-04],
#          [ 2.6685e-04, -2.5488e-04],
#          ...,
#          [ 5.3227e-04, -3.1530e-04],
#          [ 6.4766e-05,  5.5444e-04],
#          [ 5.6823e-05, -2.3981e-04]],
#
#         [[-3.7346e-04, -7.7727e-04],
#          [-5.8543e-04, -4.0821e-04],
#          [ 2.9447e-04, -2.4752e-04],
#          ...,
#          [ 5.1021e-04, -3.3348e-04],
#          [ 5.1518e-05,  5.9870e-04],
#          [ 6.9657e-05, -2.6830e-04]]], device='cuda:0'), 'base_model.model.model.layers.3.mlp.up_proj.lora_A.weight': tensor([[[ 0.2720,  0.4126, -0.1105,  ...,  2.2831, -0.3209,  0.1813],
#          [-0.2127,  1.1981,  0.9398,  ...,  1.0684,  0.0691,  2.0552]],
#
#         [[ 0.1532,  0.3109,  0.0441,  ...,  2.2211, -0.2111,  0.1688],
#          [-0.1031,  1.2622,  0.8460,  ...,  1.0041,  0.0227,  2.0040]],
#
#         [[ 0.1625,  0.2947, -0.0672,  ...,  2.0058, -0.2627,  0.2484],
#          [-0.0828,  1.3243,  0.9447,  ...,  1.0380,  0.0054,  2.0076]]],
#        device='cuda:0'), 'base_model.model.model.layers.3.mlp.up_proj.lora_B.weight': tensor([[[-4.1097e-04, -7.9953e-04],
#          [-5.9596e-04, -4.0283e-04],
#          [ 3.3569e-04, -2.5610e-04],
#          ...,
#          [ 5.1222e-04, -3.1425e-04],
#          [ 4.0598e-05,  6.1656e-04],
#          [ 8.7124e-05, -3.0287e-04]],
#
#         [[-3.9646e-04, -8.1115e-04],
#          [-6.4107e-04, -3.6310e-04],
#          [ 2.5283e-04, -2.8990e-04],
#          ...,
#          [ 5.1912e-04, -3.0661e-04],
#          [ 4.1331e-05,  6.3595e-04],
#          [ 9.7555e-05, -2.5585e-04]],
#
#         [[-3.8228e-04, -8.2544e-04],
#          [-6.0216e-04, -3.8789e-04],
#          [ 3.2809e-04, -3.0144e-04],
#          ...,
#          [ 5.1733e-04, -3.3810e-04],
#          [ 7.5415e-05,  6.0086e-04],
#          [ 9.0625e-06, -2.4414e-04]]], device='cuda:0'), 'base_model.model.model.layers.4.mlp.up_proj.lora_A.weight': tensor([[[ 0.0292,  0.3571, -0.1154,  ...,  2.2160, -0.4135,  0.1939],
#          [ 0.0660,  1.2860,  1.1013,  ...,  1.1379,  0.0167,  2.1961]],
#
#         [[ 0.1427,  0.4389, -0.1352,  ...,  2.0203, -0.4390,  0.0368],
#          [-0.1033,  1.4146,  0.8850,  ...,  1.0800,  0.0824,  2.0766]],
#
#         [[ 0.1601,  0.4255, -0.0123,  ...,  2.0542, -0.1622,  0.1721],
#          [-0.0025,  1.1936,  0.8130,  ...,  0.9837,  0.0774,  1.9632]]],
#        device='cuda:0'), 'base_model.model.model.layers.4.mlp.up_proj.lora_B.weight': tensor([[[-3.3136e-04, -8.0049e-04],
#          [-6.2014e-04, -3.4016e-04],
#          [ 3.2713e-04, -2.9817e-04],
#          ...,
#          [ 5.3388e-04, -3.1448e-04],
#          [ 1.2266e-05,  6.7618e-04],
#          [ 1.7641e-05, -2.2473e-04]],
#
#         [[-4.1109e-04, -7.7846e-04],
#          [-5.9835e-04, -3.9193e-04],
#          [ 2.5585e-04, -2.6531e-04],
#          ...,
#          [ 5.8103e-04, -2.7980e-04],
#          [ 6.1879e-07,  6.5482e-04],
#          [ 4.3427e-05, -2.4942e-04]],
#
#         [[-3.8063e-04, -7.4084e-04],
#          [-5.7096e-04, -4.0993e-04],
#          [ 2.5870e-04, -2.7452e-04],
#          ...,
#          [ 5.2966e-04, -3.2705e-04],
#          [ 5.7612e-05,  5.7612e-04],
#          [ 3.3892e-05, -2.7767e-04]]], device='cuda:0'), 'base_model.model.model.layers.5.mlp.up_proj.lora_A.weight': tensor([[[ 0.2376,  0.3102, -0.2349,  ...,  2.2359, -0.2818,  0.1408],
#          [-0.0180,  1.2663,  0.9414,  ...,  1.0882,  0.0299,  2.0272]],
#
#         [[ 0.1734,  0.2819, -0.0931,  ...,  2.1709, -0.2041,  0.1801],
#          [ 0.0428,  1.3275,  0.9163,  ...,  0.9975,  0.0214,  1.9892]],
#
#         [[ 0.1488,  0.5275, -0.0157,  ...,  2.2233, -0.2015,  0.1634],
#          [-0.0078,  1.3788,  0.8766,  ...,  1.0388, -0.1111,  2.1081]]],
#        device='cuda:0'), 'base_model.model.model.layers.5.mlp.up_proj.lora_B.weight': tensor([[[-3.5289e-04, -8.3514e-04],
#          [-5.7031e-04, -4.1904e-04],
#          [ 2.8100e-04, -3.2373e-04],
#          ...,
#          [ 5.3931e-04, -3.0134e-04],
#          [ 8.7096e-05,  5.7244e-04],
#          [ 9.8263e-05, -2.8159e-04]],
#
#         [[-3.9534e-04, -8.3376e-04],
#          [-6.2149e-04, -4.2843e-04],
#          [ 3.2944e-04, -3.1633e-04],
#          ...,
#          [ 5.1913e-04, -3.7550e-04],
#          [ 3.8155e-05,  6.4088e-04],
#          [ 7.6558e-05, -3.0032e-04]],
#
#         [[-4.0295e-04, -7.8062e-04],
#          [-5.4909e-04, -4.2753e-04],
#          [ 2.9994e-04, -2.4839e-04],
#          ...,
#          [ 5.0356e-04, -3.2835e-04],
#          [ 4.5795e-05,  6.5309e-04],
#          [ 8.1642e-05, -2.4443e-04]]], device='cuda:0'), 'base_model.model.model.layers.6.mlp.up_proj.lora_A.weight': tensor([[[ 0.0845,  0.3537, -0.0106,  ...,  2.1710, -0.3769,  0.1640],
#          [ 0.0364,  1.1553,  0.8725,  ...,  1.0255, -0.0444,  2.0553]],
#
#         [[ 0.1151,  0.3882, -0.0914,  ...,  2.0640, -0.4407,  0.1741],
#          [-0.1145,  1.2831,  0.9124,  ...,  1.0438, -0.0566,  1.8760]],
#
#         [[ 0.1656,  0.4108, -0.0080,  ...,  1.9650, -0.3835,  0.1382],
#          [-0.1057,  1.2874,  0.7794,  ...,  0.8607, -0.0450,  1.9787]]],
#        device='cuda:0'), 'base_model.model.model.layers.6.mlp.up_proj.lora_B.weight': tensor([[[-3.2511e-04, -7.6651e-04],
#          [-5.8060e-04, -4.1279e-04],
#          [ 2.6734e-04, -2.6077e-04],
#          ...,
#          [ 4.8275e-04, -3.1709e-04],
#          [ 2.1709e-05,  6.3187e-04],
#          [ 5.0152e-05, -3.2294e-04]],
#
#         [[-3.5378e-04, -7.4238e-04],
#          [-4.9064e-04, -3.6989e-04],
#          [ 3.1175e-04, -2.7835e-04],
#          ...,
#          [ 4.5242e-04, -2.9246e-04],
#          [ 5.2062e-05,  5.9309e-04],
#          [ 1.0356e-04, -2.7520e-04]],
#
#         [[-3.9208e-04, -7.2202e-04],
#          [-5.7341e-04, -3.7083e-04],
#          [ 2.9018e-04, -2.9211e-04],
#          ...,
#          [ 5.0450e-04, -3.1403e-04],
#          [ 8.6189e-05,  5.7303e-04],
#          [ 7.7871e-05, -2.9630e-04]]], device='cuda:0'), 'base_model.model.model.layers.7.mlp.up_proj.lora_A.weight': tensor([[[ 1.8696e-01,  4.0902e-01,  2.5384e-03,  ...,  2.0320e+00,
#           -2.8382e-01,  1.5989e-01],
#          [ 3.8326e-02,  1.3182e+00,  9.9578e-01,  ...,  1.0072e+00,
#            2.3871e-02,  2.0228e+00]],
#
#         [[ 3.2169e-01,  5.0645e-01,  1.3254e-03,  ...,  2.0166e+00,
#           -1.4109e-01,  1.8981e-01],
#          [-7.8079e-02,  1.2662e+00,  8.7980e-01,  ...,  1.0195e+00,
#            8.5569e-02,  2.0982e+00]],
#
#         [[ 2.4892e-01,  2.5309e-01, -7.8093e-02,  ...,  2.0345e+00,
#           -2.8211e-01,  1.3982e-01],
#          [-3.1108e-02,  1.2171e+00,  1.0265e+00,  ...,  9.7272e-01,
#            4.8060e-02,  2.1425e+00]]], device='cuda:0'), 'base_model.model.model.layers.7.mlp.up_proj.lora_B.weight': tensor([[[-3.9119e-04, -7.4111e-04],
#          [-6.0902e-04, -3.7190e-04],
#          [ 2.7752e-04, -1.9052e-04],
#          ...,
#          [ 5.7049e-04, -3.1225e-04],
#          [ 7.6569e-05,  6.3153e-04],
#          [ 6.3226e-06, -2.3567e-04]],
#
#         [[-3.4918e-04, -8.0514e-04],
#          [-5.9414e-04, -4.2779e-04],
#          [ 2.8177e-04, -3.1693e-04],
#          ...,
#          [ 5.3250e-04, -2.9581e-04],
#          [ 5.7672e-05,  5.9788e-04],
#          [ 9.9714e-05, -2.7092e-04]],
#
#         [[-3.6840e-04, -7.4695e-04],
#          [-5.7970e-04, -4.3314e-04],
#          [ 2.8166e-04, -2.5839e-04],
#          ...,
#          [ 5.7874e-04, -3.2554e-04],
#          [ 9.7883e-05,  6.7386e-04],
#          [ 4.6275e-05, -2.8911e-04]]], device='cuda:0'), 'base_model.model.model.layers.8.mlp.up_proj.lora_A.weight': tensor([[[ 0.2442,  0.3148, -0.0371,  ...,  2.0394, -0.3592,  0.1919],
#          [-0.1615,  1.2315,  0.8869,  ...,  0.8962,  0.0745,  2.0140]],
#
#         [[ 0.1773,  0.2578, -0.0398,  ...,  2.1253, -0.2804,  0.1750],
#          [-0.0452,  1.1870,  0.9624,  ...,  1.0064,  0.0303,  2.0310]],
#
#         [[ 0.1661,  0.2302, -0.2113,  ...,  2.2199, -0.4014,  0.1039],
#          [-0.1231,  1.2509,  0.9342,  ...,  1.1832,  0.0148,  2.0930]]],
#        device='cuda:0'), 'base_model.model.model.layers.8.mlp.up_proj.lora_B.weight': tensor([[[-2.7780e-04, -7.4756e-04],
#          [-5.9670e-04, -4.3343e-04],
#          [ 2.4884e-04, -2.1992e-04],
#          ...,
#          [ 5.1007e-04, -2.7788e-04],
#          [ 5.9718e-05,  6.1042e-04],
#          [ 9.7284e-05, -3.0387e-04]],
#
#         [[-3.7054e-04, -7.8980e-04],
#          [-5.8534e-04, -4.0164e-04],
#          [ 2.9300e-04, -2.5655e-04],
#          ...,
#          [ 5.5151e-04, -3.6335e-04],
#          [ 8.7538e-05,  6.8290e-04],
#          [ 4.3209e-05, -2.7239e-04]],
#
#         [[-3.7265e-04, -7.8561e-04],
#          [-5.9677e-04, -4.3850e-04],
#          [ 3.0341e-04, -2.3721e-04],
#          ...,
#          [ 5.5107e-04, -3.2216e-04],
#          [ 9.6464e-05,  6.6686e-04],
#          [ 7.5935e-05, -3.2184e-04]]], device='cuda:0'), 'base_model.model.model.layers.9.mlp.up_proj.lora_A.weight': tensor([[[ 0.2148,  0.2317, -0.0641,  ...,  2.1019, -0.2070,  0.1834],
#          [-0.0285,  1.1501,  0.8377,  ...,  0.9270, -0.0580,  1.9412]],
#
#         [[ 0.2208,  0.2555, -0.1678,  ...,  2.0368, -0.3874,  0.1827],
#          [-0.0055,  1.3172,  0.8261,  ...,  1.0275, -0.0287,  2.0379]],
#
#         [[ 0.2753,  0.3427, -0.1493,  ...,  1.9166, -0.2660,  0.1438],
#          [-0.0030,  1.2157,  0.7719,  ...,  1.0815, -0.0261,  1.9607]]],
#        device='cuda:0'), 'base_model.model.model.layers.9.mlp.up_proj.lora_B.weight': tensor([[[-3.1455e-04, -7.5997e-04],
#          [-5.8712e-04, -3.6632e-04],
#          [ 3.1203e-04, -2.3692e-04],
#          ...,
#          [ 4.5768e-04, -3.0953e-04],
#          [ 3.8442e-05,  6.1016e-04],
#          [ 5.4543e-05, -2.2611e-04]],
#
#         [[-3.4817e-04, -7.9005e-04],
#          [-5.8689e-04, -3.5536e-04],
#          [ 3.2957e-04, -2.4812e-04],
#          ...,
#          [ 4.7838e-04, -2.9294e-04],
#          [ 3.0965e-05,  5.8448e-04],
#          [ 1.1255e-04, -2.3947e-04]],
#
#         [[-2.8823e-04, -7.1209e-04],
#          [-5.8204e-04, -3.8510e-04],
#          [ 2.9088e-04, -2.9879e-04],
#          ...,
#          [ 4.5784e-04, -3.0554e-04],
#          [ 8.4795e-06,  6.0641e-04],
#          [ 7.3279e-05, -3.0520e-04]]], device='cuda:0'), 'base_model.model.model.layers.10.mlp.up_proj.lora_A.weight': tensor([[[ 0.1885,  0.2709, -0.1230,  ...,  2.0591, -0.2970,  0.1622],
#          [-0.0171,  1.2615,  0.8855,  ...,  0.9007,  0.0606,  2.0038]],
#
#         [[ 0.2774,  0.2654, -0.0958,  ...,  2.0039, -0.3956,  0.1692],
#          [ 0.0109,  1.2400,  0.7618,  ...,  1.0257,  0.0081,  2.0209]],
#
#         [[-0.0457,  0.2275, -0.0923,  ...,  1.9148, -0.2917,  0.1668],
#          [-0.0104,  1.3442,  0.8291,  ...,  1.0735,  0.0318,  1.9752]]],
#        device='cuda:0'), 'base_model.model.model.layers.10.mlp.up_proj.lora_B.weight': tensor([[[-3.4233e-04, -7.7476e-04],
#          [-6.2917e-04, -3.8357e-04],
#          [ 2.7226e-04, -3.0895e-04],
#          ...,
#          [ 5.1023e-04, -3.2363e-04],
#          [ 4.3246e-05,  6.4000e-04],
#          [ 2.8850e-05, -2.4648e-04]],
#
#         [[-3.5955e-04, -7.3995e-04],
#          [-6.4398e-04, -4.0979e-04],
#          [ 2.9654e-04, -2.4622e-04],
#          ...,
#          [ 5.0734e-04, -2.8830e-04],
#          [ 4.2273e-05,  6.2498e-04],
#          [ 2.6795e-05, -2.3330e-04]],
#
#         [[-3.4525e-04, -7.6756e-04],
#          [-6.0267e-04, -4.6985e-04],
#          [ 3.4461e-04, -2.6765e-04],
#          ...,
#          [ 5.3693e-04, -3.5952e-04],
#          [-2.0224e-06,  6.5595e-04],
#          [ 1.8044e-05, -2.8927e-04]]], device='cuda:0'), 'base_model.model.model.layers.11.mlp.up_proj.lora_A.weight': tensor([[[ 0.1499,  0.2869, -0.0522,  ...,  1.9679, -0.3037,  0.0966],
#          [ 0.0090,  1.2741,  0.8439,  ...,  1.0871,  0.0635,  2.0281]],
#
#         [[ 0.1881,  0.4009, -0.0821,  ...,  2.0756, -0.2876,  0.1314],
#          [-0.1376,  1.1777,  0.7962,  ...,  1.0798,  0.0135,  2.1144]],
#
#         [[ 0.1805,  0.3850, -0.0173,  ...,  1.9359, -0.2960,  0.2621],
#          [ 0.1071,  1.4672,  0.8589,  ...,  1.0302, -0.1470,  2.0314]]],
#        device='cuda:0'), 'base_model.model.model.layers.11.mlp.up_proj.lora_B.weight': tensor([[[-3.7084e-04, -7.5637e-04],
#          [-5.1456e-04, -3.2755e-04],
#          [ 2.5145e-04, -2.7009e-04],
#          ...,
#          [ 5.2892e-04, -2.9445e-04],
#          [ 3.4950e-05,  5.6811e-04],
#          [ 6.9838e-05, -2.2257e-04]],
#
#         [[-3.3969e-04, -8.0648e-04],
#          [-5.7905e-04, -3.7998e-04],
#          [ 2.9060e-04, -2.3266e-04],
#          ...,
#          [ 4.6317e-04, -2.9916e-04],
#          [ 6.8131e-05,  5.8966e-04],
#          [ 2.6067e-06, -1.9415e-04]],
#
#         [[-3.5109e-04, -7.3802e-04],
#          [-6.0596e-04, -3.8027e-04],
#          [ 3.0133e-04, -2.8435e-04],
#          ...,
#          [ 5.1956e-04, -2.9090e-04],
#          [ 1.6458e-05,  6.1685e-04],
#          [ 7.7466e-05, -2.7037e-04]]], device='cuda:0'), 'base_model.model.model.layers.12.mlp.up_proj.lora_A.weight': tensor([[[ 0.1904,  0.2810, -0.1015,  ...,  1.8236, -0.3563,  0.3408],
#          [-0.0142,  1.1969,  0.7745,  ...,  0.8705, -0.0200,  1.9226]],
#
#         [[ 0.1484,  0.2258, -0.1499,  ...,  1.9202, -0.2869,  0.3063],
#          [-0.0916,  1.2055,  0.6563,  ...,  0.9299, -0.0299,  1.8726]],
#
#         [[ 0.1545,  0.4050,  0.0530,  ...,  1.8321, -0.3848,  0.2842],
#          [-0.0814,  1.2277,  0.8844,  ...,  0.9625, -0.0161,  1.8512]]],
#        device='cuda:0'), 'base_model.model.model.layers.12.mlp.up_proj.lora_B.weight': tensor([[[-3.4767e-04, -7.4419e-04],
#          [-5.4918e-04, -4.2109e-04],
#          [ 3.0581e-04, -2.3090e-04],
#          ...,
#          [ 4.9020e-04, -3.5758e-04],
#          [ 7.7047e-05,  5.6912e-04],
#          [ 3.0916e-05, -2.9662e-04]],
#
#         [[-3.5406e-04, -7.1159e-04],
#          [-5.3704e-04, -3.4920e-04],
#          [ 2.6930e-04, -2.3621e-04],
#          ...,
#          [ 5.0740e-04, -2.3452e-04],
#          [ 6.0580e-05,  5.7404e-04],
#          [ 2.7885e-05, -2.7615e-04]],
#
#         [[-3.2444e-04, -7.4937e-04],
#          [-5.6566e-04, -3.8622e-04],
#          [ 2.7187e-04, -2.4249e-04],
#          ...,
#          [ 5.1391e-04, -2.5958e-04],
#          [ 9.2201e-05,  5.9922e-04],
#          [ 7.1588e-05, -2.8456e-04]]], device='cuda:0'), 'base_model.model.model.layers.13.mlp.up_proj.lora_A.weight': tensor([[[ 1.4175e-01,  3.9392e-01, -1.1550e-01,  ...,  1.8967e+00,
#           -1.8749e-01,  1.6220e-01],
#          [-8.5154e-02,  1.1484e+00,  7.1501e-01,  ...,  1.0623e+00,
#            2.9607e-02,  1.8257e+00]],
#
#         [[ 1.7197e-01,  2.6327e-01, -8.9572e-02,  ...,  1.8983e+00,
#           -2.9272e-01,  2.4054e-01],
#          [-7.1457e-02,  1.2856e+00,  8.0706e-01,  ...,  9.6224e-01,
#           -4.7292e-02,  1.7896e+00]],
#
#         [[ 1.4777e-01,  3.7680e-01, -4.5274e-02,  ...,  1.9637e+00,
#           -2.3935e-01,  2.6864e-01],
#          [-1.2218e-01,  1.3016e+00,  7.7279e-01,  ...,  1.0364e+00,
#           -1.4720e-04,  2.1232e+00]]], device='cuda:0'), 'base_model.model.model.layers.13.mlp.up_proj.lora_B.weight': tensor([[[-4.0219e-04, -7.7770e-04],
#          [-5.1833e-04, -3.4452e-04],
#          [ 2.1728e-04, -2.6566e-04],
#          ...,
#          [ 4.9047e-04, -3.1723e-04],
#          [ 7.7809e-05,  6.0262e-04],
#          [ 5.7145e-05, -2.3607e-04]],
#
#         [[-3.4716e-04, -7.5159e-04],
#          [-5.4824e-04, -3.6257e-04],
#          [ 2.5164e-04, -2.7263e-04],
#          ...,
#          [ 4.8789e-04, -3.0016e-04],
#          [ 9.1328e-05,  5.8042e-04],
#          [ 8.1343e-05, -2.8437e-04]],
#
#         [[-3.6751e-04, -7.8281e-04],
#          [-5.6534e-04, -3.4186e-04],
#          [ 2.7814e-04, -2.6583e-04],
#          ...,
#          [ 5.1748e-04, -3.4732e-04],
#          [ 6.3306e-05,  5.8117e-04],
#          [ 6.1840e-05, -2.2423e-04]]], device='cuda:0'), 'base_model.model.model.layers.14.mlp.up_proj.lora_A.weight': tensor([[[ 1.0917e-01,  2.8530e-01, -1.0766e-01,  ...,  1.7975e+00,
#           -6.8093e-02,  2.5096e-01],
#          [ 1.4624e-02,  1.1409e+00,  8.0749e-01,  ...,  1.0922e+00,
#            6.8094e-04,  2.0080e+00]],
#
#         [[ 2.0384e-01,  2.7488e-01, -2.1628e-02,  ...,  2.1337e+00,
#           -3.0383e-01,  1.7757e-01],
#          [-9.5634e-02,  1.1981e+00,  7.4774e-01,  ...,  9.6040e-01,
#           -5.8746e-02,  2.0243e+00]],
#
#         [[ 1.3334e-01,  1.8280e-01, -1.2806e-01,  ...,  1.9012e+00,
#           -2.0565e-01,  3.7081e-01],
#          [-2.6701e-02,  1.1710e+00,  8.6700e-01,  ...,  9.2661e-01,
#           -4.1162e-02,  1.8158e+00]]], device='cuda:0'), 'base_model.model.model.layers.14.mlp.up_proj.lora_B.weight': tensor([[[-3.3452e-04, -7.0614e-04],
#          [-5.2492e-04, -3.5845e-04],
#          [ 2.5183e-04, -2.8724e-04],
#          ...,
#          [ 4.4827e-04, -3.1055e-04],
#          [ 5.8407e-05,  6.3247e-04],
#          [ 8.0643e-05, -3.1731e-04]],
#
#         [[-3.3565e-04, -7.6975e-04],
#          [-5.0044e-04, -4.3568e-04],
#          [ 2.5733e-04, -2.7034e-04],
#          ...,
#          [ 4.8038e-04, -2.7640e-04],
#          [ 3.3566e-05,  6.2755e-04],
#          [ 9.2737e-05, -2.6694e-04]],
#
#         [[-3.2957e-04, -6.6513e-04],
#          [-5.1412e-04, -3.3843e-04],
#          [ 2.4983e-04, -2.0259e-04],
#          ...,
#          [ 4.4603e-04, -2.5515e-04],
#          [ 8.1862e-05,  5.2115e-04],
#          [ 6.9759e-05, -2.3418e-04]]], device='cuda:0'), 'base_model.model.model.layers.15.mlp.up_proj.lora_A.weight': tensor([[[ 0.1296,  0.4518, -0.2109,  ...,  2.1360, -0.1942,  0.1156],
#          [-0.0553,  1.3645,  0.8995,  ...,  1.1898,  0.1630,  2.1470]],
#
#         [[ 0.1253,  0.3037, -0.0953,  ...,  2.0760, -0.3004,  0.1946],
#          [-0.0849,  1.2541,  0.9123,  ...,  0.9908,  0.0895,  2.0374]],
#
#         [[ 0.1200,  0.3897, -0.0807,  ...,  1.9490, -0.3017,  0.0497],
#          [-0.1588,  1.1984,  0.8530,  ...,  0.9110, -0.1016,  1.9635]]],
#        device='cuda:0'), 'base_model.model.model.layers.15.mlp.up_proj.lora_B.weight': tensor([[[-4.0001e-04, -8.2738e-04],
#          [-6.1661e-04, -4.1675e-04],
#          [ 2.6350e-04, -2.7913e-04],
#          ...,
#          [ 5.5893e-04, -2.9785e-04],
#          [ 8.8169e-05,  6.5580e-04],
#          [ 1.2010e-05, -3.0531e-04]],
#
#         [[-3.5094e-04, -7.2866e-04],
#          [-5.4530e-04, -3.6861e-04],
#          [ 2.6660e-04, -2.9592e-04],
#          ...,
#          [ 5.2480e-04, -2.6848e-04],
#          [ 5.5503e-05,  6.2645e-04],
#          [ 3.2694e-05, -2.9082e-04]],
#
#         [[-3.2772e-04, -6.8963e-04],
#          [-5.6024e-04, -3.4969e-04],
#          [ 2.6359e-04, -2.6096e-04],
#          ...,
#          [ 5.1092e-04, -2.5581e-04],
#          [ 7.3081e-05,  5.2629e-04],
#          [-9.2601e-07, -2.6136e-04]]], device='cuda:0'), 'base_model.model.model.layers.0.mlp.gate_proj.lora_A.weight': tensor([[[-0.0997, -1.2395,  0.1175,  ..., -0.8959, -0.2394,  2.4847],
#          [-0.5434, -0.1492,  0.8457,  ...,  0.5612, -2.5928, -1.8132]],
#
#         [[-0.1193, -1.2669, -0.2276,  ..., -0.9418, -0.0919,  2.3385],
#          [-0.3926, -0.0365,  1.1110,  ...,  0.5560, -2.4873, -1.8976]],
#
#         [[-0.1707, -1.2263, -0.1992,  ..., -0.9212, -0.1418,  2.2751],
#          [-0.5457, -0.1119,  1.0201,  ...,  0.5732, -2.5087, -2.0155]]],
#        device='cuda:0'), 'base_model.model.model.layers.0.mlp.gate_proj.lora_B.weight': tensor([[[-1.7390e-04,  2.7843e-04],
#          [ 3.7531e-04, -9.7406e-04],
#          [-6.2287e-04, -1.3810e-04],
#          ...,
#          [-5.2097e-05, -1.2155e-04],
#          [-1.7177e-04, -4.0898e-04],
#          [-1.7279e-04, -7.2211e-04]],
#
#         [[-1.4465e-04,  1.9180e-04],
#          [ 3.5714e-04, -1.0599e-03],
#          [-6.7420e-04, -2.1429e-04],
#          ...,
#          [-3.0516e-05, -1.2694e-04],
#          [-1.3152e-04, -3.8569e-04],
#          [-1.9237e-04, -7.9994e-04]],
#
#         [[-1.0107e-04,  2.2342e-04],
#          [ 3.1335e-04, -1.0208e-03],
#          [-6.4590e-04, -1.3532e-04],
#          ...,
#          [ 1.6789e-05,  2.4350e-09],
#          [-1.2152e-04, -4.1717e-04],
#          [-1.4699e-04, -7.7140e-04]]], device='cuda:0'), 'base_model.model.model.layers.1.mlp.gate_proj.lora_A.weight': tensor([[[ 0.0550, -1.2176,  0.0412,  ..., -1.1678, -0.0998,  2.4514],
#          [-0.5641, -0.0970,  1.0787,  ...,  0.5539, -2.4835, -2.0659]],
#
#         [[-0.2145, -1.2170,  0.0352,  ..., -0.8320, -0.1996,  2.3992],
#          [-0.4009,  0.0203,  1.0079,  ...,  0.5769, -2.4817, -1.8799]],
#
#         [[-0.1122, -1.0040,  0.1408,  ..., -0.9518, -0.1101,  2.0026],
#          [-0.2995, -0.0050,  0.9699,  ...,  0.5358, -2.2625, -1.6650]]],
#        device='cuda:0'), 'base_model.model.model.layers.1.mlp.gate_proj.lora_B.weight': tensor([[[-1.3175e-04,  2.6079e-04],
#          [ 4.4657e-04, -1.0116e-03],
#          [-7.5142e-04, -1.4009e-04],
#          ...,
#          [-9.8100e-05, -4.0815e-05],
#          [-1.8902e-04, -3.9495e-04],
#          [-7.8748e-05, -7.9820e-04]],
#
#         [[-1.3240e-04,  2.5032e-04],
#          [ 3.4608e-04, -9.1758e-04],
#          [-6.8895e-04, -8.4538e-06],
#          ...,
#          [-9.2106e-05,  2.2883e-05],
#          [-1.6100e-04, -3.8591e-04],
#          [-1.3025e-04, -7.0275e-04]],
#
#         [[-1.3277e-04,  2.1777e-04],
#          [ 3.8126e-04, -8.9787e-04],
#          [-6.0576e-04, -8.7343e-05],
#          ...,
#          [-9.2413e-06, -4.8986e-05],
#          [-1.6249e-04, -3.6121e-04],
#          [-9.9220e-05, -6.6125e-04]]], device='cuda:0'), 'base_model.model.model.layers.2.mlp.gate_proj.lora_A.weight': tensor([[[-0.0537, -1.2022, -0.0826,  ..., -0.9572, -0.0182,  2.2547],
#          [-0.3501, -0.1538,  1.1201,  ...,  0.6148, -2.5332, -1.8489]],
#
#         [[-0.0060, -0.9786, -0.1317,  ..., -1.0155, -0.1319,  2.2135],
#          [-0.5480, -0.1976,  0.9907,  ...,  0.5661, -2.3236, -1.7650]],
#
#         [[-0.2610, -1.1916, -0.0410,  ..., -0.8698, -0.2379,  2.3743],
#          [-0.3718, -0.1829,  0.9830,  ...,  0.6256, -2.3833, -1.7903]]],
#        device='cuda:0'), 'base_model.model.model.layers.2.mlp.gate_proj.lora_B.weight': tensor([[[-1.0348e-04,  3.4467e-04],
#          [ 3.7202e-04, -1.0527e-03],
#          [-7.4487e-04, -1.5213e-04],
#          ...,
#          [-3.3556e-05,  7.1209e-06],
#          [-1.8921e-04, -4.7462e-04],
#          [-1.5853e-04, -8.0861e-04]],
#
#         [[-1.9649e-04,  2.1853e-04],
#          [ 4.0098e-04, -9.5027e-04],
#          [-6.3725e-04, -6.5380e-05],
#          ...,
#          [-2.3553e-05, -2.0016e-05],
#          [-1.2105e-04, -3.4279e-04],
#          [-1.7659e-04, -7.0906e-04]],
#
#         [[-1.6070e-04,  3.0222e-04],
#          [ 3.7780e-04, -9.3105e-04],
#          [-6.3705e-04, -9.4265e-05],
#          ...,
#          [-1.5987e-05,  8.9753e-06],
#          [-1.9152e-04, -3.9117e-04],
#          [-1.5551e-04, -7.6036e-04]]], device='cuda:0'), 'base_model.model.model.layers.3.mlp.gate_proj.lora_A.weight': tensor([[[-0.0475, -1.2100, -0.0894,  ..., -1.0013, -0.2694,  2.3445],
#          [-0.4784, -0.1241,  1.0515,  ...,  0.6188, -2.3262, -1.9924]],
#
#         [[ 0.1525, -1.2147, -0.0896,  ..., -0.9197, -0.1088,  2.3068],
#          [-0.4482, -0.1968,  1.2043,  ...,  0.7506, -2.4196, -1.7797]],
#
#         [[-0.0713, -1.2740, -0.1299,  ..., -0.8395, -0.1873,  2.3336],
#          [-0.4695, -0.0777,  1.0924,  ...,  0.5754, -2.5201, -1.8016]]],
#        device='cuda:0'), 'base_model.model.model.layers.3.mlp.gate_proj.lora_B.weight': tensor([[[-1.5369e-04,  2.5672e-04],
#          [ 3.7608e-04, -1.0053e-03],
#          [-7.1319e-04, -1.6399e-04],
#          ...,
#          [ 7.3365e-06, -1.0322e-04],
#          [-1.3680e-04, -4.6645e-04],
#          [-2.0457e-04, -7.4842e-04]],
#
#         [[-1.4623e-04,  2.3506e-04],
#          [ 3.6375e-04, -9.4921e-04],
#          [-7.3203e-04, -1.0212e-04],
#          ...,
#          [ 3.2665e-05, -5.7525e-05],
#          [-1.8976e-04, -3.7055e-04],
#          [-1.2867e-04, -7.5471e-04]],
#
#         [[-1.0647e-04,  3.0428e-04],
#          [ 3.9359e-04, -9.4891e-04],
#          [-6.8750e-04, -1.4039e-04],
#          ...,
# ...
#          [-0.3587, -0.0875,  1.0309,  ...,  0.5153, -2.4777, -1.8790]],
#
#         [[-0.1637, -1.1780, -0.0974,  ..., -0.8820, -0.1414,  2.3509],
#          [-0.4665, -0.0750,  0.9988,  ...,  0.4522, -2.3186, -1.6867]],
#
#         [[-0.0908, -1.0760,  0.1161,  ..., -1.1105, -0.0815,  2.1273],
#          [-0.4040, -0.1978,  1.0344,  ...,  0.5520, -2.5879, -1.6816]]],
#        device='cuda:0'), 'base_model.model.model.layers.4.mlp.gate_proj.lora_B.weight': tensor([[[-1.3551e-04,  1.8921e-04],
#          [ 4.6527e-04, -9.8032e-04],
#          [-7.3179e-04, -9.1527e-05],
#          ...,
#          [-3.9330e-05, -7.9384e-06],
#          [-1.5762e-04, -3.9199e-04],
#          [-9.5926e-05, -7.6024e-04]],
#
#         [[-1.8029e-04,  3.1407e-04],
#          [ 3.8167e-04, -1.0126e-03],
#          [-6.4253e-04, -1.6883e-04],
#          ...,
#          [-5.0530e-05, -8.0027e-05],
#          [-2.4166e-04, -4.5902e-04],
#          [-1.4813e-04, -8.3304e-04]],
#
#         [[-7.4585e-05,  2.3418e-04],
#          [ 3.3494e-04, -9.3328e-04],
#          [-7.3135e-04, -8.8885e-05],
#          ...,
#          [-6.4467e-05, -1.0652e-04],
#          [-2.1486e-04, -3.8658e-04],
#          [-9.0534e-05, -6.7108e-04]]], device='cuda:0'), 'base_model.model.model.layers.5.mlp.gate_proj.lora_A.weight': tensor([[[-0.1572, -1.3057, -0.1688,  ..., -0.9081, -0.2318,  2.2857],
#          [-0.4822, -0.0400,  0.9809,  ...,  0.6427, -2.5570, -1.8257]],
#
#         [[-0.2188, -1.3231, -0.2080,  ..., -0.9791,  0.0085,  2.5212],
#          [-0.6874, -0.2418,  0.9248,  ...,  0.5739, -2.8397, -2.1021]],
#
#         [[-0.1436, -1.4027, -0.0300,  ..., -0.8550, -0.1918,  2.3674],
#          [-0.5691, -0.2107,  1.1177,  ...,  0.5121, -2.4899, -1.8760]]],
#        device='cuda:0'), 'base_model.model.model.layers.5.mlp.gate_proj.lora_B.weight': tensor([[[-1.3186e-04,  2.9740e-04],
#          [ 3.1487e-04, -1.0590e-03],
#          [-5.5491e-04, -1.7412e-04],
#          ...,
#          [-1.8018e-05, -4.7704e-05],
#          [-1.5700e-04, -4.2477e-04],
#          [-1.2454e-04, -8.4425e-04]],
#
#         [[-1.7633e-04,  3.4604e-04],
#          [ 3.8390e-04, -1.0793e-03],
#          [-6.7965e-04, -2.0390e-04],
#          ...,
#          [-1.0558e-05, -1.5347e-05],
#          [-1.3505e-04, -4.7011e-04],
#          [-1.6198e-04, -8.7409e-04]],
#
#         [[-1.4794e-04,  2.5448e-04],
#          [ 3.9698e-04, -1.0300e-03],
#          [-5.6729e-04, -2.3345e-04],
#          ...,
#          [ 3.4360e-05, -1.1716e-05],
#          [-1.5549e-04, -4.3626e-04],
#          [-1.2780e-04, -7.9673e-04]]], device='cuda:0'), 'base_model.model.model.layers.6.mlp.gate_proj.lora_A.weight': tensor([[[ 0.0329, -1.3418, -0.4013,  ..., -0.7955, -0.0689,  2.4556],
#          [-0.4461, -0.0574,  1.0539,  ...,  0.5135, -2.7174, -1.9228]],
#
#         [[-0.1051, -1.4205, -0.0676,  ..., -0.9391, -0.0229,  2.2423],
#          [-0.8160, -0.1767,  0.9376,  ...,  0.5909, -2.6604, -2.0372]],
#
#         [[-0.2389, -1.4124, -0.1332,  ..., -0.8095, -0.0159,  2.2125],
#          [-0.6509, -0.0861,  0.8981,  ...,  0.5410, -2.8075, -1.7863]]],
#        device='cuda:0'), 'base_model.model.model.layers.6.mlp.gate_proj.lora_B.weight': tensor([[[-1.5642e-04,  2.3158e-04],
#          [ 3.2016e-04, -1.0519e-03],
#          [-5.8891e-04, -2.2598e-04],
#          ...,
#          [-9.3099e-05, -1.1004e-04],
#          [-2.0049e-04, -5.1089e-04],
#          [-2.3309e-04, -7.8294e-04]],
#
#         [[-2.0559e-04,  3.0264e-04],
#          [ 3.8231e-04, -1.0138e-03],
#          [-6.8891e-04, -1.5624e-04],
#          ...,
#          [ 2.6528e-05, -5.2418e-05],
#          [-1.2720e-04, -5.0458e-04],
#          [-1.4638e-04, -8.3584e-04]],
#
#         [[-2.5602e-04,  2.5585e-04],
#          [ 3.6209e-04, -1.0574e-03],
#          [-6.8808e-04, -2.3221e-04],
#          ...,
#          [ 3.7494e-05, -8.6413e-05],
#          [-1.6723e-04, -4.8503e-04],
#          [-1.3796e-04, -8.3195e-04]]], device='cuda:0'), 'base_model.model.model.layers.7.mlp.gate_proj.lora_A.weight': tensor([[[-0.2464, -1.2890,  0.0404,  ..., -0.8486, -0.0211,  2.4396],
#          [-0.6130, -0.1255,  1.0549,  ...,  0.5596, -2.5686, -1.9334]],
#
#         [[-0.2106, -1.1945, -0.0256,  ..., -1.0062, -0.2675,  2.1074],
#          [-0.5762, -0.0746,  0.9204,  ...,  0.4139, -2.5572, -1.9291]],
#
#         [[-0.1971, -1.2554, -0.0678,  ..., -0.8511, -0.1237,  2.2508],
#          [-0.5379, -0.2050,  1.0442,  ...,  0.6137, -2.5716, -1.6999]]],
#        device='cuda:0'), 'base_model.model.model.layers.7.mlp.gate_proj.lora_B.weight': tensor([[[-6.7472e-05,  3.8841e-04],
#          [ 3.7346e-04, -1.0559e-03],
#          [-6.5018e-04, -1.2765e-04],
#          ...,
#          [-7.5839e-06, -5.3146e-05],
#          [-2.3340e-04, -3.8632e-04],
#          [-1.2244e-04, -7.6583e-04]],
#
#         [[-1.7938e-04,  3.0657e-04],
#          [ 3.8634e-04, -9.9256e-04],
#          [-6.2400e-04, -1.8263e-04],
#          ...,
#          [-3.2402e-05, -5.1841e-06],
#          [-1.5756e-04, -3.8890e-04],
#          [-1.7576e-04, -7.1064e-04]],
#
#         [[-1.3679e-04,  2.7934e-04],
#          [ 3.4396e-04, -9.4520e-04],
#          [-5.5883e-04, -1.3345e-04],
#          ...,
#          [ 1.1250e-06, -1.1244e-04],
#          [-1.5872e-04, -3.7650e-04],
#          [-1.1342e-04, -7.0357e-04]]], device='cuda:0'), 'base_model.model.model.layers.8.mlp.gate_proj.lora_A.weight': tensor([[[-0.0892, -1.0973, -0.0503,  ..., -0.8672, -0.2241,  2.4702],
#          [-0.4889, -0.0564,  1.1018,  ...,  0.6065, -2.6165, -1.7942]],
#
#         [[-0.0337, -1.0765,  0.0905,  ..., -1.0797, -0.0635,  2.1895],
#          [-0.4402, -0.2323,  1.0300,  ...,  0.6047, -2.4370, -1.8850]],
#
#         [[-0.1496, -1.1429, -0.1562,  ..., -1.0823, -0.1797,  2.2500],
#          [-0.4775, -0.1401,  1.0548,  ...,  0.6964, -2.7351, -1.8913]]],
#        device='cuda:0'), 'base_model.model.model.layers.8.mlp.gate_proj.lora_B.weight': tensor([[[-1.3960e-04,  3.6672e-04],
#          [ 3.2144e-04, -1.0760e-03],
#          [-6.8228e-04, -1.3597e-04],
#          ...,
#          [-4.1747e-05, -2.9776e-05],
#          [-1.4371e-04, -4.2305e-04],
#          [-1.7042e-04, -7.8847e-04]],
#
#         [[-1.2505e-04,  2.3516e-04],
#          [ 3.4571e-04, -9.8387e-04],
#          [-7.2546e-04, -1.5996e-04],
#          ...,
#          [-9.0774e-05, -7.8017e-05],
#          [-2.4260e-04, -3.9134e-04],
#          [-8.7151e-05, -7.7998e-04]],
#
#         [[-1.3600e-04,  3.0249e-04],
#          [ 3.2385e-04, -1.0099e-03],
#          [-6.8681e-04, -1.8127e-04],
#          ...,
#          [-5.4836e-05, -1.0921e-04],
#          [-1.4756e-04, -4.2566e-04],
#          [-1.7342e-04, -7.3243e-04]]], device='cuda:0'), 'base_model.model.model.layers.9.mlp.gate_proj.lora_A.weight': tensor([[[-0.0538, -1.0126,  0.0165,  ..., -1.1143, -0.2277,  2.4201],
#          [-0.2725, -0.0822,  1.1450,  ...,  0.8225, -2.3587, -2.0159]],
#
#         [[-0.2204, -0.9743,  0.1763,  ..., -1.0443, -0.2535,  2.3726],
#          [-0.3055,  0.0029,  1.0296,  ...,  0.8466, -2.4028, -1.7878]],
#
#         [[-0.1982, -1.0373,  0.1647,  ..., -1.0258, -0.1903,  2.3571],
#          [-0.4450,  0.0325,  0.9987,  ...,  0.6454, -2.4101, -1.8472]]],
#        device='cuda:0'), 'base_model.model.model.layers.9.mlp.gate_proj.lora_B.weight': tensor([[[-4.2623e-05,  2.8402e-04],
#          [ 4.4115e-04, -8.9863e-04],
#          [-7.1909e-04, -7.1152e-05],
#          ...,
#          [-6.6797e-05, -5.9737e-05],
#          [-1.4373e-04, -3.8764e-04],
#          [-7.9857e-05, -6.1937e-04]],
#
#         [[-5.9482e-05,  3.0419e-04],
#          [ 4.0711e-04, -8.8693e-04],
#          [-7.4006e-04, -8.7169e-05],
#          ...,
#          [-4.8887e-05, -8.2696e-05],
#          [-2.2934e-04, -3.7018e-04],
#          [-6.8872e-05, -7.6893e-04]],
#
#         [[-1.6753e-04,  3.2766e-04],
#          [ 4.4857e-04, -8.9365e-04],
#          [-7.0975e-04, -1.0620e-04],
#          ...,
#          [-9.5580e-06,  4.0628e-06],
#          [-1.8680e-04, -3.5294e-04],
#          [-8.8696e-05, -7.1689e-04]]], device='cuda:0'), 'base_model.model.model.layers.10.mlp.gate_proj.lora_A.weight': tensor([[[-0.3067, -0.8118,  0.1873,  ..., -1.2243, -0.2625,  2.0461],
#          [-0.2622,  0.0348,  1.0841,  ...,  0.8102, -2.3429, -1.7087]],
#
#         [[-0.0664, -0.8554,  0.0885,  ..., -1.2170, -0.2986,  2.2703],
#          [-0.2711,  0.1398,  0.8458,  ...,  0.8612, -2.3992, -1.8561]],
#
#         [[-0.1227, -0.7557,  0.1268,  ..., -1.0736, -0.1435,  2.1096],
#          [-0.1996, -0.0482,  1.0579,  ...,  0.7467, -2.2193, -1.6773]]],
#        device='cuda:0'), 'base_model.model.model.layers.10.mlp.gate_proj.lora_B.weight': tensor([[[-4.8985e-05,  3.5441e-04],
#          [ 4.3193e-04, -7.9224e-04],
#          [-7.7666e-04,  4.0431e-05],
#          ...,
#          [-4.5898e-05,  8.4317e-06],
#          [-1.6297e-04, -3.2619e-04],
#          [-1.0506e-04, -5.8409e-04]],
#
#         [[-5.2823e-05,  3.0324e-04],
#          [ 4.1246e-04, -8.2327e-04],
#          [-7.4156e-04,  4.5638e-06],
#          ...,
#          [-4.9738e-05, -3.3956e-05],
#          [-6.7104e-05, -2.3553e-04],
#          [-2.7073e-05, -6.5525e-04]],
#
#         [[ 5.0107e-06,  2.6662e-04],
#          [ 3.3384e-04, -7.9227e-04],
#          [-6.9007e-04,  3.2776e-05],
#          ...,
#          [-1.1810e-04, -1.1260e-04],
#          [-2.1198e-04, -2.2260e-04],
#          [-3.4900e-05, -6.6601e-04]]], device='cuda:0'), 'base_model.model.model.layers.11.mlp.gate_proj.lora_A.weight': tensor([[[-0.0592, -1.0253,  0.1551,  ..., -0.7791, -0.1043,  2.2521],
#          [-0.3694,  0.0156,  0.9807,  ...,  0.5795, -2.4702, -1.6829]],
#
#         [[-0.2100, -1.0855, -0.0874,  ..., -0.7697, -0.0783,  2.3639],
#          [-0.3280, -0.0473,  1.0704,  ...,  0.6627, -2.4044, -1.7501]],
#
#         [[-0.1968, -0.9934,  0.1411,  ..., -0.9681, -0.2460,  2.3767],
#          [-0.3806,  0.0693,  1.0734,  ...,  0.5563, -2.4937, -1.9137]]],
#        device='cuda:0'), 'base_model.model.model.layers.11.mlp.gate_proj.lora_B.weight': tensor([[[-1.4223e-04,  1.8581e-04],
#          [ 3.4820e-04, -9.3813e-04],
#          [-6.4288e-04, -1.1529e-04],
#          ...,
#          [-1.4812e-04, -3.5146e-05],
#          [-1.1737e-04, -4.0442e-04],
#          [-1.5404e-04, -7.1128e-04]],
#
#         [[-6.5046e-05,  2.6157e-04],
#          [ 3.9844e-04, -9.8381e-04],
#          [-6.4315e-04, -1.5394e-04],
#          ...,
#          [-5.4943e-06, -2.9903e-05],
#          [-1.3387e-04, -3.3706e-04],
#          [-1.4861e-04, -7.3632e-04]],
#
#         [[-8.7337e-05,  3.0958e-04],
#          [ 4.2064e-04, -9.9982e-04],
#          [-7.0277e-04, -7.7499e-05],
#          ...,
#          [-2.9682e-05, -4.7722e-05],
#          [-1.6844e-04, -3.4783e-04],
#          [-1.5201e-04, -7.6147e-04]]], device='cuda:0'), 'base_model.model.model.layers.12.mlp.gate_proj.lora_A.weight': tensor([[[-0.1593, -0.9322,  0.1984,  ..., -1.0584, -0.1164,  2.0754],
#          [-0.3052,  0.1864,  0.9081,  ...,  0.7311, -2.2127, -1.6019]],
#
#         [[-0.1560, -0.8662,  0.0811,  ..., -1.0967, -0.1745,  2.1600],
#          [-0.3210,  0.1622,  0.9590,  ...,  0.6826, -2.2239, -1.8548]],
#
#         [[-0.2031, -0.8302,  0.1925,  ..., -1.3379, -0.2130,  2.1259],
#          [-0.3091,  0.1035,  1.0124,  ...,  0.8413, -2.4491, -1.8602]]],
#        device='cuda:0'), 'base_model.model.model.layers.12.mlp.gate_proj.lora_B.weight': tensor([[[-2.6788e-05,  2.5791e-04],
#          [ 4.4197e-04, -7.8213e-04],
#          [-6.1640e-04,  3.3524e-06],
#          ...,
#          [-1.0075e-04, -3.9352e-05],
#          [-1.3964e-04, -3.3628e-04],
#          [-5.2858e-05, -5.2784e-04]],
#
#         [[-1.4199e-05,  2.8912e-04],
#          [ 4.4064e-04, -8.1095e-04],
#          [-7.1806e-04,  1.5733e-05],
#          ...,
#          [-2.7792e-05, -6.0160e-05],
#          [-1.2638e-04, -2.9043e-04],
#          [-1.4025e-04, -6.6308e-04]],
#
#         [[-1.4002e-05,  2.5930e-04],
#          [ 3.9338e-04, -8.3684e-04],
#          [-7.7467e-04,  6.8370e-06],
#          ...,
#          [-7.4963e-05, -1.7108e-05],
#          [-1.3762e-04, -3.2425e-04],
#          [-1.1236e-04, -6.7852e-04]]], device='cuda:0'), 'base_model.model.model.layers.13.mlp.gate_proj.lora_A.weight': tensor([[[-0.0954, -0.7805,  0.2340,  ..., -1.0122, -0.2394,  2.1804],
#          [-0.1801,  0.0499,  1.0128,  ...,  0.8462, -2.2585, -1.7763]],
#
#         [[-0.0371, -0.7579,  0.0393,  ..., -1.1665, -0.2311,  2.3080],
#          [-0.3111,  0.1442,  1.0186,  ...,  0.9895, -2.3588, -1.8262]],
#
#         [[-0.1349, -0.7962,  0.3104,  ..., -1.2388, -0.2261,  2.2070],
#          [-0.2057,  0.1635,  0.9759,  ...,  0.8707, -2.3465, -1.8784]]],
#        device='cuda:0'), 'base_model.model.model.layers.13.mlp.gate_proj.lora_B.weight': tensor([[[-1.1633e-04,  1.9806e-04],
#          [ 3.8232e-04, -7.2314e-04],
#          [-7.8984e-04,  6.5382e-05],
#          ...,
#          [-4.3100e-05, -5.7223e-05],
#          [-9.8537e-05, -3.3955e-04],
#          [-7.3785e-05, -5.7370e-04]],
#
#         [[-9.4082e-05,  3.1135e-04],
#          [ 4.6242e-04, -7.8329e-04],
#          [-7.3344e-04, -5.2923e-06],
#          ...,
#          [ 3.7099e-06, -5.8872e-05],
#          [-6.6974e-05, -2.8685e-04],
#          [-2.0581e-06, -5.3317e-04]],
#
#         [[-1.1357e-04,  2.7494e-04],
#          [ 4.5563e-04, -8.0977e-04],
#          [-7.4660e-04,  1.1170e-04],
#          ...,
#          [-2.3353e-06, -5.0551e-05],
#          [-1.4885e-04, -2.3910e-04],
#          [-4.5530e-05, -5.6388e-04]]], device='cuda:0'), 'base_model.model.model.layers.14.mlp.gate_proj.lora_A.weight': tensor([[[-0.0111, -0.8829,  0.0371,  ..., -1.1252, -0.0394,  2.1174],
#          [-0.5117,  0.0386,  1.1153,  ...,  0.6611, -2.4379, -1.7653]],
#
#         [[-0.0348, -1.0049,  0.1502,  ..., -1.0728, -0.0893,  2.2065],
#          [-0.4767,  0.0584,  0.9873,  ...,  0.7035, -2.5019, -1.5642]],
#
#         [[-0.1298, -1.0223,  0.1660,  ..., -1.1064, -0.2854,  2.3669],
#          [-0.4700, -0.0805,  1.0475,  ...,  0.6734, -2.3892, -1.8724]]],
#        device='cuda:0'), 'base_model.model.model.layers.14.mlp.gate_proj.lora_B.weight': tensor([[[-9.5104e-05,  3.2669e-04],
#          [ 3.9342e-04, -8.6669e-04],
#          [-7.5056e-04,  9.1359e-05],
#          ...,
#          [-3.7833e-05, -3.6707e-05],
#          [-1.4893e-04, -3.3506e-04],
#          [-1.5143e-04, -7.1187e-04]],
#
#         [[-8.5894e-05,  2.6430e-04],
#          [ 3.7338e-04, -9.1451e-04],
#          [-7.2174e-04, -5.9403e-06],
#          ...,
#          [-3.7449e-05, -4.4229e-05],
#          [-1.1069e-04, -2.9853e-04],
#          [-1.2034e-04, -6.0690e-04]],
#
#         [[-1.0760e-04,  3.3477e-04],
#          [ 4.9314e-04, -9.5376e-04],
#          [-6.1260e-04, -5.8401e-05],
#          ...,
#          [-3.6788e-05,  1.8444e-05],
#          [-1.6653e-04, -3.6952e-04],
#          [-1.5263e-04, -6.6774e-04]]], device='cuda:0'), 'base_model.model.model.layers.15.mlp.gate_proj.lora_A.weight': tensor([[[ 0.0532, -1.0997,  0.1296,  ..., -1.0319, -0.0270,  2.1259],
#          [-0.4222, -0.0514,  0.9761,  ...,  0.6742, -2.1283, -1.7392]],
#
#         [[-0.0059, -0.9941,  0.0375,  ..., -1.0860, -0.0370,  2.2822],
#          [-0.3382,  0.0728,  0.9062,  ...,  0.7713, -2.3358, -1.6522]],
#
#         [[-0.1748, -1.0588,  0.0050,  ..., -1.1873, -0.2380,  2.3717],
#          [-0.3527,  0.0385,  1.1209,  ...,  0.8228, -2.4177, -1.9021]]],
#        device='cuda:0'), 'base_model.model.model.layers.15.mlp.gate_proj.lora_B.weight': tensor([[[-7.0997e-05,  2.1894e-04],
#          [ 3.8760e-04, -8.5651e-04],
#          [-6.7563e-04, -5.2587e-05],
#          ...,
#          [-1.2039e-04, -1.4549e-04],
#          [-1.3316e-04, -3.1829e-04],
#          [-7.5551e-05, -6.1176e-04]],
#
#         [[-1.5083e-04,  3.3610e-04],
#          [ 4.1594e-04, -8.7059e-04],
#          [-7.0920e-04, -7.3063e-05],
#          ...,
#          [-4.7270e-05, -3.9156e-05],
#          [-1.8004e-04, -3.5329e-04],
#          [-1.0134e-04, -7.3024e-04]],
#
#         [[-1.1362e-04,  3.1193e-04],
#          [ 4.4147e-04, -8.7807e-04],
#          [-7.3190e-04, -9.4820e-05],
#          ...,
#          [-1.7950e-05, -5.6162e-05],
#          [-1.2999e-04, -3.5219e-04],
#          [-7.9047e-05, -6.6271e-04]]], device='cuda:0')})
# 96
# torch.Size([3, 2, 2048])
# torch.Size([3, 8192, 2])
# torch.Size([3, 2, 2048])
# torch.Size([3, 8192, 2])
# torch.Size([3, 2, 8192])
# torch.Size([3, 2048, 2])

# %%
import json

dataset = json.load(open("data_aug_deepseek-v3/2wikimultihopqa/train_passages_deduplication_0_30000.json", "r"))
passages=[]
for sample in dataset:
    passages.append({'passage':sample['passages'][0]})
with open("./data_aug_deepseek-v3/2wikimultihopqa/reconstruct_passage_train.json", "w") as f:
    json.dump(passages[:-100], f, indent=4)
with open("./data_dev_inference_104/reconstruct_passage_test.json", "w") as f:
    json.dump(passages[-100:], f, indent=4)
